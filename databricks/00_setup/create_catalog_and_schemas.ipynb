-- %%
create catalog if not exists vendor_status;

-- %%
create schema if not exists vendor_status.bronze;
create schema if not exists vendor_status.silver;
create schema if not exists vendor_status.gold;
create schema if not exists vendor_status.ops;
